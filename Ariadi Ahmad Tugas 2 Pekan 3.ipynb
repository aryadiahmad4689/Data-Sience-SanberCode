# %% [markdown]
# <h2>Soal 1:</h2>
#
# Dengan menggunakan data di bawah ini, plot kan data tersebut kemudian custom sehingga memiliki result seperti yang di harapkan :
#
# note: warna terdiri dari warna Hijau, kuning, Biru, dan Merah

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
cos = np.cos(x)
cos3 = np.cos(x)*3
sin = np.sin(x-90)
sin2 = np.sin(x)*2

# %%
# code here
fig,ax = plt.subplots()
ax.plot(x,cos,color='red',label='cos x')
ax.plot(x,cos3,color='green', linestyle='dashed', label='3 cos')
ax.plot(x,sin,color='blue',linestyle='-.',label='sin x(-90)')
ax.plot(x,sin2,color='yellow', linestyle='',marker='x',label='2 sin x')
ax.legend(loc=10)
ax.set_ylabel('Y-Axis-Label')
ax.set_xlabel('X-Axis-Label')
ax.set_title('Grafik Cos Sin')
# Out:
# Text(0.5, 1.0, 'Grafik Cos Sin')

# %% [markdown]
# Expected Result:
#
# ![alt text](https://drive.google.com/uc?id=1XRcfWyiWLDmriw7s7U4fTn5Gs6s2qf5o)
